# %% [markdown]
# # Polynomial Regression Practice
# The following data set will follow $$y = ax^2 + bx + c$$

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print("All libraries are successfully imported")
# Out:
# All libraries are successfully imported

# %%
df = pd.read_csv('polynomial_regression.csv')
print(df.head())
# Out:
#            X           Y
# 0 -10.000000  282.856110
# 1  -9.797980  263.680919
# 2  -9.595960  293.915038
# 3  -9.393939  242.271581
# 4  -9.191919  225.436453

# %%
#Plot the data to understand 
plt.scatter(df["X"],df["Y"])
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.title("Non Linear Data")
plt.show()

# %%
#Prepare the features
X = df[["X"]]
y = df["Y"]

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
#Plot Polynomial Curve 
plt.scatter(X,y)
plt.plot(X,model.predict(X_poly),color='red')
plt.title("Polynomial Regression")
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.show()
